# %%
# USE THIS COMMANDE TO INSTALL OLLAMA

# !curl -fsSL https://ollama.com/install.sh | sed 's#https://ollama.com/download#https://github.com/jmorganca/ollama/releases/download/v0.1.27#' | sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !pip install aiohttp pyngrok

import os
import asyncio

# Set LD_LIBRARY_PATH so the system NVIDIA library
os.environ.update({'LD_LIBRARY_PATH': '/usr/lib64-nvidia'})

async def run_process(cmd):
  print('>>> starting', *cmd)
  p = await asyncio.subprocess.create_subprocess_exec(
      *cmd,
      stdout=asyncio.subprocess.PIPE,
      stderr=asyncio.subprocess.PIPE,
  )

  async def pipe(lines):
    async for line in lines:
      print(line.strip().decode('utf-8'))

  await asyncio.gather(
      pipe(p.stdout),
      pipe(p.stderr),
  )

#register an account at ngrok.com and create an authtoken and place it here
await asyncio.gather(
    run_process(['ngrok', 'config', 'add-authtoken','2KNtUMJKMrNDEuEglEgf8uwpbM3_6nUcECDzeLtHx5TYh1vcf'])
)

await asyncio.gather(
    run_process(['ollama', 'serve']),
    run_process(['ollama', 'pull','mistral:7b-instruct-v0.2-q4_0']),
    run_process(['ngrok', 'http', '--log', 'stderr', '11434']),
)
# Out:
# ...
# >>> starting ngrok config add-authtoken 2KNtUMJKMrNDEuEglEgf8uwpbM3_6nUcECDzeLtHx5TYh1vcf
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# >>> starting ollama serve
# >>> starting ollama pull mistral:7b-instruct-v0.2-q4_0
# >>> starting ngrok http --log stderr 11434
# time=2024-06-02T19:24:00.111Z level=INFO source=images.go:710 msg="total blobs: 0"
# time=2024-06-02T19:24:00.111Z level=INFO source=images.go:717 msg="total unused blobs removed: 0"
# time=2024-06-02T19:24:00.111Z level=INFO source=routes.go:1019 msg="Listening on 127.0.0.1:11434 (version 0.1.27)"
# time=2024-06-02T19:24:00.112Z level=INFO source=payload_common.go:107 msg="Extracting dynamic libraries..."
# t=2024-06-02T19:24:00+0000 lvl=info msg="no configuration paths supplied"
# t=2024-06-02T19:24:00+0000 lvl=info msg="using configuration at default config path" path=/root/.config/ngrok/ngrok.yml
# ...

# %% [markdown]
# Ngrok exposes a url, which you the have to export as OLLAMA_HOST
#
# `export OLLAMA_HOST=https://fd90-34-125-15-193.ngrok.io/`
#
# after that we can use ollama on our remote instance from our local machine.
